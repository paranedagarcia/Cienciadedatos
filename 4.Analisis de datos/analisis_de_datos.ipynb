# %% [markdown]
# # 📊 Análisis de Datos
# **Objetivo del módulo:** Aprender a manipular y analizar datasets.
#
# **Resultados de Aprendizaje:**
# - Crear y transformar DataFrames.
# - Limpiar y preparar datos.
#
# **Contenidos:**
# 1. Numpy arrays y operaciones
# 2. Introducción a Pandas
# 3. Limpieza: nulos, duplicados, tipos
# 4. Lectura y escritura de archivos
# 5. Exploración, transformación y limpieza con pandas
# 6. Transformaciones: merge, pivot, apply
# 7. EDA:Correlaciones, segmentación y valores atípicos, Análisis automático

# %% [markdown]
# ## Diccionario de datos
#
#
# | COLUMNA                  | DESCRIPCION                           |
# |--------------------------|---------------------------------------|
# | COTIZACION               | Número de cotización                  |
# | RESERVA                  | Número de reserva                     |
# | RAZON_COMPRA             | Razón de compra                       |
# | FORMA_PAGO               | Forma de pago                         |
# | GRUPO_LLEGADA            | Grupo de llegada                      |
# | MEDIO_LLEGADA            | Medio de llegada                      |
# | ORIGEN_VENTA             | Origen de venta                       |
# | ORIGEN_VISITA            | Origen de visita                      |
# | UNIDAD                   | Número de la unidad (departamento)    |
# | PISO                     | Número de piso                        |
# | ORIENTACION              | Orientación del departamento          |
# | TIPOLOGIA                | Tipología                             |
# | METROS                   | Metros cuadrados                      |
# | PRECIO_VENTA                   | Precio                                |
# | DESCUENTO                | Descuento sobre el precio             |
# | ESTADO                   | Estado                                |
# | ESTADO_PRODUCTO          | Estado del producto                   |
# | FECHA_VISITA             | Fecha de visita                       |
# | FECHA_COTIZACION         | Fecha de cotización                   |
# | FECHA_RESERVA            | Fecha de reserva                      |
# | FECHA_PROMESA            | Fecha de promesa                      |
# | FECHA_RESCILIACION       | Fecha de resciliación                 |
# | FECHA_ESCRITURACION      | Fecha de escrituración                |
# | FECHA_AGENDADA           | Fecha de agendada                     |
# | FECHA_ENTREGA            | Fecha de entrega del departamento     |
# | DIAS_COTIZACION          | Días de cotización                    |
# | DIAS_RESERVA             | Días de reserva                       |
# | DIAS_PROMESA             | Días de promesa                       |
# | DIAS_ESCRITURACION       | Días de escrituración                 |
# | DIAS_ENTREGA             | Días de entrega                       |
# | PROYECTO                 | Nombre del proyecto                   |
# | IDPROYECTO               | ID del proyecto                       |
# | DIRECCION                | Dirección (calle y número)            |
# | COMUNA                   | Comuna del proyecto                   |
# | REGION_PROYECTO          | Región del proyecto                   |
# | LATITUD                  | Latitud                               |
# | LONGITUD                 | Longitud                              |
# | MOTIVO_RESCILIACION      | Motivo de resciliación                |
# | BANCO_HIPOTECARIO        | Banco hipotecario                     |
# | PAGO_CONTADO             | Pago al contado                       |
# | MOTIVO_DESISTIMIENTO     | Motivo de desistimiento               |
# | SubMotivoDesistimiento   | Submotivo de desistimiento            |
# | COMUNA_PROYECTO          | Comuna del proyecto                   |
# | FECHA_LIBERACION         | Fecha de liberación                   |
# | CLIENTE                  | Identificación del Cliente            |
# | NACIMIENTO               | Fecha de nacimiento                   |
# | EDAD                     | Edad                                  |
# | SEXO                     | Sexo                                  |
# | ESTADO_CIVIL             | Estado civil                          |
# | HIJOS                    | Número de hijos                       |
# | OCUPACION                | Ocupación                             |
# | NACIONALIDAD             | Nacionalidad del cliente              |
# | COMUNA_CLIENTE           | Comuna del cliente                    |
# | REGION                   | Región del cliente                    |
# | INGRESO                  | Nivel de ingresos                     |

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

df = pd.read_csv('../data/ventas.csv')

# mostrar todas las columnas del DataFrame
pd.set_option('display.max_columns', None)
df.head()
# Out:
# /tmp/ipykernel_48027/1306158443.py:7: DtypeWarning: Columns (15,16,17,18,19,26,28,29,30,31,32,33,34,35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/ventas.csv')
#    idoperacion      RAZON_COMPRA                       FORMA_PAGO  \
# 0      22969.0         INVERSION                              HIP
# 1      17189.0  PRIMERA VIVIENDA       PIE CUOTAS/PIE CONTADO/HIP
# 2      11852.0  PRIMERA VIVIENDA               PIE CUOTAS/HIP/BON
# 3       1387.0         INVERSION   PIE CUOTAS/PIE CONTADO/HIP/BON
# 4      18833.0         INVERSION                  PIE CONTADO/HIP
#
#    GRUPO_LLEGADA         MEDIO_LLEGADA ORIGEN_VENTA   TIPO UNIDAD  PISO  \
# 0   OTROS MEDIOS              AL PASAR      Interna  DEPTO   1101    11
# 1   OTROS MEDIOS  FERIAS INMOBILIARIAS      Interna  DEPTO   207B     2
# 2   OTROS MEDIOS              AL PASAR      Interna  DEPTO   507B     5
# 3  CARGA INICIAL             MIGRACION      Interna  DEPTO   608B     6
# 4  CARGA INICIAL             MIGRACION      Interna  DEPTO  406 A     4
#
#    ORIENTACION TIPOLOGIA METROS  PRECIO_VENTA FECHAVISITA FECHACOTIZACION  \
# 0     PONIENTE     1D/1B  35,67       3026.10  2022-10-21      2022-10-21
# 1        NORTE   2D/2B/K  57,73       3566.40  2020-01-25      2020-01-25
# 2  SUR ORIENTE     2D/2B  77,11       5948.36  2018-06-17      2018-06-17
# 3          SUR  1D/1B CA  40,26       3302.14  2017-01-09      2017-01-09
# 4      ORIENTE   1,5D/1B  51,83       3907.00  2020-11-13      2020-11-13
#
#   FECHARESERVA FECHAPROMESA FECHAESCRITURACION FechaAgendada FechaEntrega  \
# 0   2022-10-21          NaN                NaN           NaN          NaN
# 1   2020-01-25          NaN                NaN           NaN          NaN
# 2   2018-06-17   2018-06-21         2020-04-13    2020-05-13   2020-05-13
# 3   2015-12-02   2015-12-02                NaN           NaN          NaN
# 4   2020-11-13   2015-12-29         2020-10-28    2020-12-18   2020-12-18
#
#    DIAS_COTIZACION  DIAS_RESERVA  DIAS_PROMESA  DIAS_ESCRITURACION  \
# 0              0.0           0.0           NaN                 NaN
# 1              0.0           0.0           NaN                 NaN
# 2              0.0           0.0           4.0               662.0
# 3              0.0        -404.0           0.0                 NaN
# 4              0.0           0.0       -1781.0              1765.0
#
#    DIAS_ENTREGA ORIGEN_VISITA      ESTADO                       PROYECTO  \
# 0           NaN    Presencial  RESCILIADA               CONCEPTO MORE II
# 1           NaN    Presencial  RESCILIADA  CONCEPTO SMART VICUÑA TORRE B
# 2          30.0    Presencial    APROBADA                 CONCEPTO SMART
# 3           NaN     Distancia  RESCILIADA                 CONCEPTO SMART
# 4          51.0     Distancia    APROBADA                 CONCEPTO SMART
#
#   PrecioLista Descuento FechaResciliacion                 MotivoResciliacion  \
# 0        3930       696        2022-10-24                     PARA REINGRESA
# 1        4452    934,92        2020-01-26                 CAMBIO DE PROYECTO
# 2        6357   1090,86               NaN                                NaN
# 3           0         0        2020-09-03  TRANSACCION CON RESERVA DE FONDOS
# 4           0         0               NaN                                NaN
#
#   BancoHipotecario PagoContado MotivoDesistimiento SubMotivoDesistimiento  \
# 0              NaN          NO                 NaN                    NaN
# 1              NaN          NO                 NaN                    NaN
# 2  Banco Consorcio          NO                 NaN                    NaN
# 3              NaN          NO                 NaN                    NaN
# 4  Banco Santander          NO                 NaN                    NaN
#
#   ComunaProyecto FechaLiberacion FechaNacimiento  Edad genero EstadoCivil  \
# 0   Stgo. Centro             NaN      2009-07-03  15.0      M      CASADO
# 1    San Joaquin             NaN             NaN   NaN      M         NaN
# 2          Ñuñoa      2020-04-09      1990-09-07  33.0      M     SOLTERO
# 3          Ñuñoa             NaN      1974-11-11  49.0      F     SOLTERO
# 4          Ñuñoa      2020-11-18      1970-06-10  53.0      M      CASADO
#
#    NroHijos                Ocupacion Nacionalidad ComunaCliente  \
# 0       0.0            Inversionista        Chile         Lampa
# 1       NaN      Ingeniero Comercial        Chile   Providencia
# 2       NaN  Ingeniero Civil Quimico        Chile         Ñuñoa
# 3       0.0          Ingeniero Civil        Chile      La Reina
# 4       0.0          Ingeniero Civil        Chile  Lo Barnechea
#
#                  Region             Ingresorenta
# 0  REGIÓN METROPOLITANA        Más de $3.000.000
# 1  REGIÓN METROPOLITANA  $1.200.001 - $1.800.000
# 2  REGIÓN METROPOLITANA  $2.000.001 - $3.000.000
# 3  REGIÓN METROPOLITANA             NO INFORMADO
# 4  REGIÓN METROPOLITANA           0 - $1.000.000

# %%
# eliminar filas con Edad nula
antes = df.shape[0]
df.dropna(subset=['Edad'], inplace=True)
df.drop('idoperacion', axis=1, inplace=True)
despues = df.shape[0]
print(f"Filas eliminadas: {antes-despues} | Nuevo shape: {df.shape}")
# Out:
# Filas eliminadas: 377050 | Nuevo shape: (84703, 47)

# %%
# eliminar registros con las columnas '_PRECIO_VENTA_num'Y 'PRECIO_POR_M2' nulo o cero
antes = df.shape[0]
df = df[(df['_PRECIO_VENTA_num'].notna()) & (df['_PRECIO_VENTA_num'] != 0)]
df = df[(df['PRECIO_POR_M2'].notna()) & (df['PRECIO_POR_M2'] != 0)]
despues = df.shape[0]
print(f"Filas eliminadas por PRECIO_VENTA_num y PRECIO_POR_M2: {antes-despues} | Nuevo shape: {df.shape}")
# Out:
# Filas eliminadas por PRECIO_VENTA_num y PRECIO_POR_M2: 84425 | Nuevo shape: (278, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84703 entries, 0 to 461747
# Data columns (total 47 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   RAZON_COMPRA            84699 non-null  object
#  1   FORMA_PAGO              84699 non-null  object
#  2   GRUPO_LLEGADA           84696 non-null  object
#  3   MEDIO_LLEGADA           84696 non-null  object
#  4   ORIGEN_VENTA            84699 non-null  object
#  5   TIPO                    84703 non-null  object
#  6   UNIDAD                  84703 non-null  object
#  7   PISO                    84703 non-null  int64
#  8   ORIENTACION             84703 non-null  object
#  9   TIPOLOGIA               84703 non-null  object
#  10  METROS                  84703 non-null  object
#  11  PRECIO_VENTA            84699 non-null  float64
#  12  FECHAVISITA             84699 non-null  object
#  13  FECHACOTIZACION         84699 non-null  object
#  14  FECHARESERVA            14017 non-null  object
#  15  FECHAPROMESA            7201 non-null   object
#  16  FECHAESCRITURACION      4353 non-null   object
#  17  FechaAgendada           4288 non-null   object
#  18  FechaEntrega            4287 non-null   object
#  19  DIAS_COTIZACION         84699 non-null  float64
#  20  DIAS_RESERVA            14017 non-null  float64
#  21  DIAS_PROMESA            7201 non-null   float64
#  22  DIAS_ESCRITURACION      4350 non-null   float64
#  23  DIAS_ENTREGA            4262 non-null   float64
#  24  ORIGEN_VISITA           84699 non-null  object
#  25  ESTADO                  14017 non-null  object
#  26  PROYECTO                84699 non-null  object
#  27  PrecioLista             14021 non-null  object
#  28  Descuento               14021 non-null  object
#  29  FechaResciliacion       8644 non-null   object
#  30  MotivoResciliacion      8644 non-null   object
#  31  BancoHipotecario        3900 non-null   object
#  32  PagoContado             14021 non-null  object
#  33  MotivoDesistimiento     1186 non-null   object
#  34  SubMotivoDesistimiento  732 non-null    object
#  35  ComunaProyecto          84703 non-null  object
#  36  FechaLiberacion         4259 non-null   object
#  37  FechaNacimiento         84687 non-null  object
#  38  Edad                    84703 non-null  float64
#  39  genero                  84703 non-null  object
#  40  EstadoCivil             84697 non-null  object
#  41  NroHijos                55700 non-null  float64
#  42  Ocupacion               80206 non-null  object
#  43  Nacionalidad            84657 non-null  object
#  44  ComunaCliente           84697 non-null  object
#  45  Region                  84697 non-null  object
#  46  Ingresorenta            84703 non-null  object
# dtypes: float64(8), int64(1), object(38)
# memory usage: 31.0+ MB

# %%
# elimina todos los registros con valores cero en columna 'PRECIO_VENTA'
antes = df.shape[0]
df = df[df['PRECIO_VENTA'] != 0]
despues = df.shape[0]
print(f"Filas eliminadas con PRECIO_VENTA == 0: {antes-despues} | Nuevo shape: {df.shape}")
# Out:
# Filas eliminadas con PRECIO_VENTA == 0: 70691 | Nuevo shape: (14012, 47)

# %%
# eliminar columnas que inician con 'DIAS' ya que no son relevantes para el análisis
dias_cols = [col for col in df.columns if col.upper().startswith('DIAS')]
df.drop(columns=dias_cols, inplace=True)
print(f"Columnas eliminadas que comienzan con 'DIAS': {dias_cols}")

# eliminar columnas 'PrecioLista' y 'PagoContado' que no son relevantes para el análisis
df.drop(columns=['PrecioLista', 'PagoContado', 'Descuento'], inplace=True)
print("Columnas eliminadas: 'PrecioLista', 'PagoContado', 'Descuento'")
# Out:
# Columnas eliminadas que comienzan con 'DIAS': []
# Columnas eliminadas: 'PrecioLista', 'PagoContado', 'Descuento'
# /tmp/ipykernel_48027/2993386570.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=dias_cols, inplace=True)
# /tmp/ipykernel_48027/2993386570.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['PrecioLista', 'PagoContado', 'Descuento'], inplace=True)

# %%
df.describe()
# Out:
#                PISO      METROS  PRECIO_VENTA                    FECHAVISITA  \
# count  14012.000000  278.000000  14008.000000                          14008
# mean       7.894019   64.151079   5184.613796  2020-04-27 12:17:22.375785472
# min        1.000000   27.000000     11.000000            2016-01-30 00:00:00
# 25%        4.000000   58.000000   3382.200000            2018-06-04 00:00:00
# 50%        7.000000   58.000000   4335.750000            2019-10-09 00:00:00
# 75%       10.000000   70.000000   6075.745000            2022-03-10 00:00:00
# max       24.000000   98.000000  27023.710000            2024-10-07 00:00:00
# std        4.767551   19.145053   2720.796755                            NaN
#
#                      FECHACOTIZACION                   FECHARESERVA  \
# count                          14008                          14008
# mean   2020-04-24 05:04:41.667618560  2020-03-29 16:07:01.473443584
# min              2016-01-30 00:00:00            2013-07-01 00:00:00
# 25%              2018-06-04 00:00:00            2018-06-04 00:00:00
# 50%              2019-10-09 00:00:00            2019-10-10 00:00:00
# 75%              2022-03-03 00:00:00            2022-02-26 06:00:00
# max              2024-10-07 00:00:00            2024-10-07 00:00:00
# std                              NaN                            NaN
#
#                         FECHAPROMESA             FECHAESCRITURACION  \
# count                           7200                           4349
# mean   2019-07-18 17:51:35.999999744  2021-03-20 18:42:27.896068096
# min              2013-02-28 00:00:00            2014-06-23 00:00:00
# 25%              2017-10-31 00:00:00            2019-08-13 00:00:00
# 50%              2019-03-29 00:00:00            2021-09-30 00:00:00
# 75%              2021-04-29 00:00:00            2022-12-21 00:00:00
# max              2024-10-08 00:00:00            2024-10-27 00:00:00
# std                              NaN                            NaN
#
#                        FechaAgendada                   FechaEntrega  \
# count                           4287                           4286
# mean   2021-04-20 19:29:56.221133824  2021-04-20 17:42:21.670555392
# min              2016-09-09 00:00:00            2016-09-09 00:00:00
# 25%              2019-09-10 00:00:00            2019-09-10 00:00:00
# 50%              2021-10-26 00:00:00            2021-10-26 00:00:00
# 75%              2023-01-17 00:00:00            2023-01-17 00:00:00
# max              2024-10-04 00:00:00            2024-10-04 00:00:00
# std                              NaN                            NaN
#
#                    FechaResciliacion                FechaLiberacion  \
# count                           8637                           4259
# mean   2020-12-02 15:28:09.336575232  2021-04-16 22:41:13.256633088
# min              2016-06-16 00:00:00            2016-08-24 00:00:00
# 25%              2019-02-07 00:00:00            2019-09-03 00:00:00
# 50%              2020-09-15 00:00:00            2021-10-13 00:00:00
# 75%              2022-10-24 00:00:00            2023-01-03 00:00:00
# max              2024-10-08 00:00:00            2024-10-08 00:00:00
# std                              NaN                            NaN
#
#                      FechaNacimiento          Edad     NroHijos
# count                          13993  14012.000000  9184.000000
# mean   1982-06-08 10:32:40.923318784     38.296175     0.122605
# min              1790-04-01 00:00:00  -5956.000000     0.000000
# 25%              1976-02-25 00:00:00     35.000000     0.000000
# 50%              1983-03-15 00:00:00     41.000000     0.000000
# 75%              1989-04-27 00:00:00     48.000000     0.000000
# max              2080-01-01 00:00:00    234.000000     5.000000
# std                              NaN    135.127469     0.493003

# %%
# convertir columnas 'METROS','PrecioLista', 'Descuento', 'PagoContado' a numérica, forzando errores a NaN
for col in ['METROS']:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    
# convertir columnas que inician con 'FECHA' a tipo date 
fecha_cols = [col for col in df.columns if col.lower().startswith('fecha')]
for col in fecha_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
# genera un pairplot de las variables numéricas
sns.pairplot(df.select_dtypes(include=['number']))
plt.show()

# %%
from scipy.stats import pearsonr, spearmanr

# EDA completo sobre 'df' (ventas / cotizaciones de departamentos)
# Nota: aprovecha imports ya presentes en el notebook (pd, sns, plt, stats, sm)

sns.set(style='whitegrid', rc={'figure.figsize':(10,5)})

def eda_report(df):
    print("1) Dimensiones y tipos")
    print("- shape:", df.shape)
    print("- columnas:", len(df.columns))
    display(df.dtypes)

    print("\n2) Valores faltantes (por columna, %)")
    miss = df.isna().mean().sort_values(ascending=False)
    display(pd.DataFrame({'missing_pct': miss}).head(30))

    print("\n3) Estadísticas descriptivas (numéricas)")
    display(df.describe(percentiles=[.01, .05, .1, .25, .5, .75, .9, .95, .99]).T)

    # skewness, kurtosis, zeros
    num = df.select_dtypes(include=['number']).columns.tolist()
    stats_df = []
    for c in num:
        col = df[c].dropna()
        stats_df.append((c, col.skew(), col.kurtosis(), (col==0).sum(), col.isna().sum()))
    stats_df = pd.DataFrame(stats_df, columns=['col','skew','kurtosis','n_zeros','n_missing']).set_index('col')
    display(stats_df.sort_values('skew', key=abs, ascending=False).head(20))

    print("\n4) Columnas categóricas: top frecuencias")
    cat = df.select_dtypes(include=['object','category']).columns.tolist()
    for c in [c for c in ['FORMA_PAGO','ESTADO','PROYECTO','ComunaProyecto','ORIGEN_VENTA'] if c in df.columns]:
        print(f"\n- {c}:")
        display(df[c].value_counts(dropna=False).head(20))

    print("\n5) Variables de fecha (rango & missing)")
    fecha_cols = [c for c in df.columns if 'FECHA' in c.upper() or 'Fecha' in c]
    for c in fecha_cols:
        if pd.api.types.is_datetime64_any_dtype(df[c]):
            s = df[c]
            print(f"{c}: min={s.min()}, max={s.max()}, missing={s.isna().mean():.2%}")
        else:
            print(f"{c}: no es datetime (tipo={df[c].dtype})")

    # Creaciones útiles
    if 'METROS' in df.columns and 'PRECIO_VENTA' in df.columns:
        df['_PRECIO_VENTA_num'] = pd.to_numeric(df['PRECIO_VENTA'], errors='coerce')
        df['PRECIO_POR_M2'] = df['_PRECIO_VENTA_num'] / df['METROS']
        print("\n6) Precio por m2: resumen")
        display(df['PRECIO_POR_M2'].describe(percentiles=[.01,.05,.1,.25,.5,.75,.9,.95,.99]))

    # Correlaciones
    print("\n7) Matriz de correlación (numéricas principales)")
    num_for_corr = ['METROS','_PRECIO_VENTA_num','Edad','DIAS_COTIZACION','DIAS_RESERVA']
    num_for_corr = [c for c in num_for_corr if c in df.columns]
    if num_for_corr:
        corr = df[num_for_corr].corr(method='pearson')
        display(corr)
        plt.figure(figsize=(6,5))
        sns.heatmap(corr, annot=True, fmt='.2f', cmap='vlag', center=0)
        plt.title('Correlación (Pearson)')
        plt.show()

    # Gráficos univariados relevantes
    print("\n8) Distribuciones (METROS, PRECIO_VENTA, PRECIO_POR_M2)")
    plot_cols = [c for c in ['METROS','_PRECIO_VENTA_num','PRECIO_POR_M2'] if c in df.columns]
    for c in plot_cols:
        s = df[c].dropna()
        if s.empty: 
            continue
        plt.figure(figsize=(10,3))
        plt.subplot(1,3,1)
        sns.histplot(s, bins=60, kde=True)
        plt.title(f'{c} (raw)')
        plt.subplot(1,3,2)
        sns.boxplot(x=s)
        plt.title('boxplot')
        plt.subplot(1,3,3)
        sns.histplot(np.log1p(s[s>0]), bins=60, kde=True)
        plt.title('log1p')
        plt.tight_layout()
        plt.show()

    # Bivariado: METROS vs PRECIO_VENTA con regresión robusta y outliers
    if 'METROS' in df.columns and '_PRECIO_VENTA_num' in df.columns:
        s_x = df['METROS'].dropna()
        s_y = df['_PRECIO_VENTA_num'].dropna()
        ix = s_x.index.intersection(s_y.index)
        plt.figure(figsize=(8,5))
        sns.regplot(x=df.loc[ix,'METROS'], y=df.loc[ix,'_PRECIO_VENTA_num'], scatter_kws={'s':8,'alpha':0.4}, line_kws={'color':'red'})
        plt.xlabel('METROS')
        plt.ylabel('PRECIO_VENTA')
        plt.title('METROS vs PRECIO_VENTA (regresión)')
        plt.show()

        # estadísticos de correlación
        try:
            print("Pearson r:", pearsonr(df.loc[ix,'METROS'], df.loc[ix,'_PRECIO_VENTA_num']))
            print("Spearman rho:", spearmanr(df.loc[ix,'METROS'], df.loc[ix,'_PRECIO_VENTA_num']))
        except Exception as e:
            print("Error calculando correlaciones:", e)

    # Agrupamientos / pivot tables útiles
    print("\n9) Precio por m2 promedio por TIPOLOGIA y por ComunaProyecto (top 20)")
    if 'PRECIO_POR_M2' in df.columns:
        if 'TIPOLOGIA' in df.columns:
            display(df.groupby('TIPOLOGIA')['PRECIO_POR_M2'].agg(['count','median','mean','std']).sort_values('count', ascending=False).head(20))
        if 'ComunaProyecto' in df.columns:
            display(df.groupby('ComunaProyecto')['PRECIO_POR_M2'].agg(['count','median','mean']).sort_values('count', ascending=False).head(20))

    # Tendencias temporales: conteos y precio medio por mes (FECHACOTIZACION preferida)
    print("\n10) Tendencias temporales (FECHACOTIZACION)")
    if 'FECHACOTIZACION' in df.columns and pd.api.types.is_datetime64_any_dtype(df['FECHACOTIZACION']):
        tmp = df.set_index('FECHACOTIZACION').resample('M').agg({'_PRECIO_VENTA_num':['count','median','mean']})
        tmp.columns = ['_'.join(c) for c in tmp.columns]
        display(tmp.tail(12))
        ax = tmp['_PRECIO_VENTA_num_mean'].plot(title='Precio medio por mes (últimos registros)', legend=False)
        ax.set_ylabel('Precio medio')
        plt.show()

    # Outliers: IQR method para precio y metros
    print("\n11) Detección outliers (IQR) en METROS y PRECIO_VENTA")
    outlier_summary = {}
    for c in ['METROS','_PRECIO_VENTA_num','PRECIO_POR_M2']:
        if c in df.columns:
            s = df[c].dropna()
            q1,q3 = s.quantile([0.25,0.75])
            iqr = q3-q1
            low = q1 - 1.5*iqr
            high = q3 + 1.5*iqr
            n_out = ((s < low) | (s > high)).sum()
            outlier_summary[c] = {'low':low,'high':high,'n_outliers':int(n_out),'pct_outliers': n_out/len(s)}
    display(pd.DataFrame(outlier_summary).T)

    # Recomendaciones rápidas
    print("\n12) Recomendaciones rápidas:")
    print("- Revisar alta proporción de nulos en 'METROS' y varias fechas; imputar o filtrar según análisis.")
    print("- Para análisis de precios usar 'PRECIO_POR_M2' y winsorizar o log-transform si conviene.")
    print("- Agrupar por TIPOLOGIA/ComunaProyecto/PROYECTO para comparar valores y detectar anomalías por subgrupos.")
    print("- Verificar registros con PRECIO_VENTA==0 o METROS==0; pueden ser errores o placeholders.")
    print("- Documentar transformaciones y filtrados antes de modelar.")

# Ejecutar reporte
eda_report(df)
# Out:
# 1) Dimensiones y tipos
# - shape: (84703, 49)
# - columnas: 49
# RAZON_COMPRA                      object
# FORMA_PAGO                        object
# GRUPO_LLEGADA                     object
# MEDIO_LLEGADA                     object
# ORIGEN_VENTA                      object
# TIPO                              object
# UNIDAD                            object
# PISO                               int64
# ORIENTACION                       object
# TIPOLOGIA                         object
# METROS                           float64
# PRECIO_VENTA                     float64
# FECHAVISITA               datetime64[ns]
# FECHACOTIZACION           datetime64[ns]
# FECHARESERVA              datetime64[ns]
# FECHAPROMESA              datetime64[ns]
# FECHAESCRITURACION        datetime64[ns]
# FechaAgendada             datetime64[ns]
# FechaEntrega              datetime64[ns]
# DIAS_COTIZACION                  float64
# DIAS_RESERVA                     float64
# DIAS_PROMESA                     float64
# DIAS_ESCRITURACION               float64
# DIAS_ENTREGA                     float64
# ORIGEN_VISITA                     object
# ESTADO                            object
# PROYECTO                          object
# PrecioLista                       object
# Descuento                         object
# FechaResciliacion         datetime64[ns]
# MotivoResciliacion                object
# BancoHipotecario                  object
# PagoContado                       object
# MotivoDesistimiento               object
# SubMotivoDesistimiento            object
# ComunaProyecto                    object
# FechaLiberacion           datetime64[ns]
# FechaNacimiento           datetime64[ns]
# Edad                             float64
# genero                            object
# EstadoCivil                       object
# NroHijos                         float64
# Ocupacion                         object
# Nacionalidad                      object
# ComunaCliente                     object
# Region                            object
# Ingresorenta                      object
# _PRECIO_VENTA_num                float64
# PRECIO_POR_M2                    float64
# dtype: object
# 2) Valores faltantes (por columna, %)
#                         missing_pct
# SubMotivoDesistimiento     0.991358
# MotivoDesistimiento        0.985998
# PRECIO_POR_M2              0.983838
# METROS                     0.983838
# BancoHipotecario           0.953957
# FechaLiberacion            0.949718
# DIAS_ENTREGA               0.949683
# FechaEntrega               0.949388
# FechaAgendada              0.949376
# DIAS_ESCRITURACION         0.948644
# FECHAESCRITURACION         0.948609
# DIAS_PROMESA               0.914985
# FECHAPROMESA               0.914985
# MotivoResciliacion         0.897949
# FechaResciliacion          0.897949
# FECHARESERVA               0.834516
# DIAS_RESERVA               0.834516
# ESTADO                     0.834516
# PagoContado                0.834469
# PrecioLista                0.834469
# Descuento                  0.834469
# NroHijos                   0.342408
# Ocupacion                  0.053091
# FechaNacimiento            0.000697
# Nacionalidad               0.000543
# GRUPO_LLEGADA              0.000083
# MEDIO_LLEGADA              0.000083
# EstadoCivil                0.000071
# ComunaCliente              0.000071
# Region                     0.000071
# 3) Estadísticas descriptivas (numéricas)
#                       count                           mean  \
# PISO                84703.0                       7.499475
# METROS               1369.0                      68.010226
# PRECIO_VENTA        84699.0                     857.460773
# FECHAVISITA           84699  2020-07-07 02:26:54.536180736
# FECHACOTIZACION       84699  2020-07-06 13:22:11.590691840
# FECHARESERVA          14017  2020-03-29 09:42:17.233359616
# FECHAPROMESA           7201  2019-07-18 14:07:52.934314496
# FECHAESCRITURACION     4353  2021-03-19 23:56:01.819434752
# FechaAgendada          4288  2021-04-20 12:03:21.492537344
# FechaEntrega           4287  2021-04-20 10:15:42.197340672
# DIAS_COTIZACION     84699.0                      -0.544941
# DIAS_RESERVA        14017.0                     -25.527431
# DIAS_PROMESA         7201.0                     -64.663102
# DIAS_ESCRITURACION   4350.0                     761.222759
# DIAS_ENTREGA         4262.0                      37.590802
# FechaResciliacion      8644  2020-12-02 00:04:09.884312832
# FechaLiberacion        4259  2021-04-16 22:41:13.256632832
# FechaNacimiento       84644  1982-12-15 19:11:30.194225216
# Edad                84703.0                      38.760268
# NroHijos            55700.0                       0.130539
# _PRECIO_VENTA_num   84699.0                     857.460773
# PRECIO_POR_M2        1369.0                       15.35664
#
#                                     min                             1%  \
# PISO                                1.0                            2.0
# METROS                             27.0                           34.0
# PRECIO_VENTA                        0.0                            0.0
# FECHAVISITA         2016-01-30 00:00:00            2017-02-12 00:00:00
# FECHACOTIZACION     2016-01-30 00:00:00            2017-02-12 00:00:00
# FECHARESERVA        2013-07-01 00:00:00            2015-05-20 00:00:00
# FECHAPROMESA        2013-02-28 00:00:00            2014-10-31 00:00:00
# FECHAESCRITURACION  2014-06-23 00:00:00            2017-05-09 12:28:48
# FechaAgendada       2016-09-09 00:00:00            2017-06-05 00:00:00
# FechaEntrega        2016-09-09 00:00:00            2017-06-05 00:00:00
# DIAS_COTIZACION                 -1897.0                            0.0
# DIAS_RESERVA                    -3270.0                         -718.0
# DIAS_PROMESA                    -1958.0                        -1467.0
# DIAS_ESCRITURACION              -1012.0                           1.49
# DIAS_ENTREGA                     -450.0                            4.0
# FechaResciliacion   2016-06-16 00:00:00            2017-04-26 00:00:00
# FechaLiberacion     2016-08-24 00:00:00            2017-07-19 00:00:00
# FechaNacimiento     1790-04-01 00:00:00  1951-11-12 04:48:00.000000192
# Edad                            -5956.0                            2.0
# NroHijos                            0.0                            0.0
# _PRECIO_VENTA_num                   0.0                            0.0
# PRECIO_POR_M2                       0.0                            0.0
#
#                                      5%                  10%  \
# PISO                                2.0                  2.0
# METROS                             45.0                 52.8
# PRECIO_VENTA                        0.0                  0.0
# FECHAVISITA         2017-06-13 00:00:00  2017-11-05 00:00:00
# FECHACOTIZACION     2017-06-13 00:00:00  2017-11-05 00:00:00
# FECHARESERVA        2016-08-06 00:00:00  2017-05-29 00:00:00
# FECHAPROMESA        2015-08-30 00:00:00  2016-04-04 00:00:00
# FECHAESCRITURACION  2017-10-10 14:24:00  2018-05-08 00:00:00
# FechaAgendada       2017-11-15 00:00:00  2018-06-07 00:00:00
# FechaEntrega        2017-11-15 00:00:00  2018-06-07 00:00:00
# DIAS_COTIZACION                     0.0                  0.0
# DIAS_RESERVA                     -197.0                  0.0
# DIAS_PROMESA                     -782.0                -46.0
# DIAS_ESCRITURACION                 23.0                 39.0
# DIAS_ENTREGA                       13.0                 16.0
# FechaResciliacion   2017-10-19 00:00:00  2018-02-26 07:12:00
# FechaLiberacion     2017-11-09 00:00:00  2018-06-01 00:00:00
# FechaNacimiento     1962-09-26 00:00:00  1968-02-07 00:00:00
# Edad                               28.0                 31.0
# NroHijos                            0.0                  0.0
# _PRECIO_VENTA_num                   0.0                  0.0
# PRECIO_POR_M2                       0.0                  0.0
#
#                                     25%                  50%  \
# PISO                                4.0                  7.0
# METROS                             58.0                 58.0
# PRECIO_VENTA                        0.0                  0.0
# FECHAVISITA         2018-09-26 00:00:00  2020-02-22 00:00:00
# FECHACOTIZACION     2018-09-26 00:00:00  2020-02-22 00:00:00
# FECHARESERVA        2018-06-04 00:00:00  2019-10-09 00:00:00
# FECHAPROMESA        2017-10-31 00:00:00  2019-03-29 00:00:00
# FECHAESCRITURACION  2019-08-13 00:00:00  2021-09-29 00:00:00
# FechaAgendada       2019-09-10 00:00:00  2021-10-26 00:00:00
# FechaEntrega        2019-09-10 00:00:00  2021-10-26 00:00:00
# DIAS_COTIZACION                     0.0                  0.0
# DIAS_RESERVA                        0.0                  0.0
# DIAS_PROMESA                        0.0                  7.0
# DIAS_ESCRITURACION                174.0                771.5
# DIAS_ENTREGA                       22.0                 30.0
# FechaResciliacion   2019-02-07 00:00:00  2020-09-15 00:00:00
# FechaLiberacion     2019-09-03 00:00:00  2021-10-13 00:00:00
# FechaNacimiento     1977-06-14 00:00:00  1984-08-13 00:00:00
# Edad                               35.0                 39.0
# NroHijos                            0.0                  0.0
# _PRECIO_VENTA_num                   0.0                  0.0
# PRECIO_POR_M2                       0.0                  0.0
#
#                                     75%                  90%  \
# PISO                               10.0                 14.0
# METROS                             98.0                 98.0
# PRECIO_VENTA                        0.0               3918.9
# FECHAVISITA         2022-05-10 00:00:00  2023-09-29 00:00:00
# FECHACOTIZACION     2022-05-09 00:00:00  2023-09-29 00:00:00
# FECHARESERVA        2022-02-26 00:00:00  2023-10-18 09:36:00
# FECHAPROMESA        2021-04-29 00:00:00  2023-04-13 00:00:00
# FECHAESCRITURACION  2022-12-21 00:00:00  2023-06-30 00:00:00
# FechaAgendada       2023-01-17 00:00:00  2023-07-27 00:00:00
# FechaEntrega        2023-01-17 00:00:00  2023-07-27 00:00:00
# DIAS_COTIZACION                     0.0                  0.0
# DIAS_RESERVA                        0.0                  0.0
# DIAS_PROMESA                       16.0                 30.0
# DIAS_ESCRITURACION               1252.0               1496.0
# DIAS_ENTREGA                       43.0                 66.0
# FechaResciliacion   2022-10-24 00:00:00  2023-12-26 00:00:00
# FechaLiberacion     2023-01-03 00:00:00  2023-07-17 00:00:00
# FechaNacimiento     1989-07-14 00:00:00  1992-11-15 00:00:00
# Edad                               47.0                 56.0
# NroHijos                            0.0                  0.0
# _PRECIO_VENTA_num                   0.0               3918.9
# PRECIO_POR_M2                       0.0            72.527345
#
#                                     95%                            99%  \
# PISO                               17.0                           22.0
# METROS                             98.0                           98.0
# PRECIO_VENTA                   5635.496                      9873.4434
# FECHAVISITA         2024-04-28 00:00:00            2024-09-06 00:00:00
# FECHACOTIZACION     2024-04-28 00:00:00            2024-09-06 00:00:00
# FECHARESERVA        2024-06-01 00:00:00            2024-09-23 00:00:00
# FECHAPROMESA        2024-03-08 00:00:00            2024-08-29 00:00:00
# FECHAESCRITURACION  2023-10-25 09:36:00  2024-07-19 09:35:59.999999744
# FechaAgendada       2023-11-24 00:00:00            2024-07-24 03:07:12
# FechaEntrega        2023-11-24 00:00:00            2024-07-24 03:21:36
# DIAS_COTIZACION                     0.0                            0.0
# DIAS_RESERVA                        1.0                          33.84
# DIAS_PROMESA                       42.0                          113.0
# DIAS_ESCRITURACION               1642.0                        1814.04
# DIAS_ENTREGA                      84.95                          153.0
# FechaResciliacion   2024-05-31 00:00:00            2024-08-29 13:40:48
# FechaLiberacion     2023-11-23 02:24:00            2024-09-01 02:24:00
# FechaNacimiento     1996-04-11 00:00:00            2022-03-11 00:00:00
# Edad                               61.0                           72.0
# NroHijos                            1.0                            3.0
# _PRECIO_VENTA_num              5635.496                      9873.4434
# PRECIO_POR_M2                 82.676693                     100.253041
#
#                                     max          std
# PISO                               24.0     4.662061
# METROS                             98.0    18.967421
# PRECIO_VENTA                   27023.71  2221.405196
# FECHAVISITA         2024-10-08 00:00:00          NaN
# FECHACOTIZACION     2024-10-08 00:00:00          NaN
# FECHARESERVA        2024-10-07 00:00:00          NaN
# FECHAPROMESA        2024-10-08 00:00:00          NaN
# FECHAESCRITURACION  2024-10-27 00:00:00          NaN
# FechaAgendada       2024-10-04 00:00:00          NaN
# FechaEntrega        2024-10-04 00:00:00          NaN
# DIAS_COTIZACION                    28.0    27.472799
# DIAS_RESERVA                     1496.0   166.091375
# DIAS_PROMESA                     1673.0   298.748275
# DIAS_ESCRITURACION               2252.0   557.733585
# DIAS_ENTREGA                     1100.0    36.751908
# FechaResciliacion   2024-10-08 00:00:00          NaN
# FechaLiberacion     2024-10-08 00:00:00          NaN
# FechaNacimiento     2080-01-01 00:00:00          NaN
# Edad                              234.0   112.761533
# NroHijos                            5.0     0.508105
# _PRECIO_VENTA_num              27023.71  2221.405196
# PRECIO_POR_M2                109.209184    30.927664
#                          skew     kurtosis  n_zeros  n_missing
# col
# DIAS_COTIZACION    -54.216543  3062.953131    84565          0
# Edad               -47.718192  2366.381626      177          0
# DIAS_ENTREGA         6.786608   197.865986        7          0
# DIAS_RESERVA        -5.102764    75.937327    11993          0
# NroHijos             4.611652    24.233592    51424          0
# DIAS_PROMESA        -3.484792    13.867791      976          0
# PRECIO_VENTA         3.257226    13.136220    70691          0
# _PRECIO_VENTA_num    3.257226    13.136220    70691          0
# PRECIO_POR_M2        1.602830     0.795180     1091          0
# PISO                 1.006901     0.667652        0          0
# METROS               0.682835    -0.911590        0          0
# DIAS_ESCRITURACION   0.102627    -1.244615       27          0
# 4) Columnas categóricas: top frecuencias
#
# - FORMA_PAGO:
# FORMA_PAGO
# REV.FOR PAGO                           70690
#  PIE CUOTAS/HIP                         4877
#  PIE CUOTAS/HIP/BON                     3339
#  PIE CUOTAS/PIE CONTADO/HIP/BON         2175
#  PIE CUOTAS/PIE CONTADO/HIP             1548
#  PIE CUOTAS/PIE CONTADO                  429
#  HIP                                     371
#  HIP/BON                                 238
#  PIE CONTADO/HIP/BON                     226
#  PIE CONTADO/HIP                         222
#  PIE CUOTAS/PIE CONTADO/AHO/HIP          135
#  PIE CONTADO                             125
#  PIE CUOTAS/AHO/HIP                      100
#  PIE CUOTAS                               67
#  PIE CUOTAS/PIE CONTADO/BON               63
#  PIE CUOTAS/PIE CONTADO/AHO/HIP/BON       25
#  PIE CONTADO/BON                          23
#  PIE CUOTAS/PIE CONTADO/SUB/HIP           16
#  AHO/HIP                                  11
#  PIE CUOTAS/AHO/HIP/BON                    8
# Name: count, dtype: int64
# - ESTADO:
# ESTADO
# NaN                     70686
# RESCILIADA               8614
# APROBADA                 5285
# PENDIENTE APROBACION      118
# Name: count, dtype: int64
# - PROYECTO:
# PROYECTO
# CONCEPTO SMART                   7284
# CONCEPTO SMART TOO               4145
# CONCEPTO ALL ÑUÑOA               3962
# CONCEPTO ORIENTE PLUS            3818
# CONCEPTO MAGIC                   3774
# CONCEPTO SMART MACUL             3159
# CONCEPTO STYLE ÑUÑOA             3060
# CONCEPTO HOMETOWN                2988
# CONCEPTO BEST SITE               2824
# CONCEPTO SMART VICUÑA TORRE B    2806
# CONCEPTO BEST LEVEL              2700
# CONCEPTO SMART CONCEPCION        2680
# CONCEPTO CIRCLE                  2488
# CONCEPTO SMART VICUÑA TORRE A    2423
# CONCEPTO MORE II                 2357
# CONCEPTO LIVING & ARTS           2262
# CONCEPTO ONETOWN                 2209
# CONCEPTO ORIGINS                 2189
# CONCEPTO BEST ÑUÑOA              2089
# CONCEPTO BEST TOO                2002
# Name: count, dtype: int64
# - ComunaProyecto:
# ComunaProyecto
# Ñuñoa            41791
# Stgo. Centro     14106
# San Joaquin       6287
# Macul             4808
# Vitacura          2889
# Las Condes        2828
# Concepcion        2680
# Viña              2511
# La Florida        2158
# Providencia       1922
# La Reina          1831
# Con Con            728
# Independencia      164
# Name: count, dtype: int64
# - ORIGEN_VENTA:
# ORIGEN_VENTA
# Interna    83760
# Externa      939
# NaN            4
# Name: count, dtype: int64
# 5) Variables de fecha (rango & missing)
# FECHAVISITA: min=2016-01-30 00:00:00, max=2024-10-08 00:00:00, missing=0.00%
# FECHACOTIZACION: min=2016-01-30 00:00:00, max=2024-10-08 00:00:00, missing=0.00%
# FECHARESERVA: min=2013-07-01 00:00:00, max=2024-10-07 00:00:00, missing=83.45%
# FECHAPROMESA: min=2013-02-28 00:00:00, max=2024-10-08 00:00:00, missing=91.50%
# FECHAESCRITURACION: min=2014-06-23 00:00:00, max=2024-10-27 00:00:00, missing=94.86%
# FechaAgendada: min=2016-09-09 00:00:00, max=2024-10-04 00:00:00, missing=94.94%
# FechaEntrega: min=2016-09-09 00:00:00, max=2024-10-04 00:00:00, missing=94.94%
# FechaResciliacion: min=2016-06-16 00:00:00, max=2024-10-08 00:00:00, missing=89.79%
# FechaLiberacion: min=2016-08-24 00:00:00, max=2024-10-08 00:00:00, missing=94.97%
# FechaNacimiento: min=1790-04-01 00:00:00, max=2080-01-01 00:00:00, missing=0.07%
#
# 6) Precio por m2: resumen
# count    1369.000000
# mean       15.356640
# std        30.927664
# min         0.000000
# 1%          0.000000
# 5%          0.000000
# 10%         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# 90%        72.527345
# 95%        82.676693
# 99%       100.253041
# max       109.209184
# Name: PRECIO_POR_M2, dtype: float64
# 7) Matriz de correlación (numéricas principales)
#                      METROS  _PRECIO_VENTA_num      Edad  DIAS_COTIZACION  \
# METROS             1.000000           0.109758  0.148257         0.014385
# _PRECIO_VENTA_num  0.109758           1.000000 -0.001197        -0.029244
# Edad               0.148257          -0.001197  1.000000        -0.000617
# DIAS_COTIZACION    0.014385          -0.029244 -0.000617         1.000000
# DIAS_RESERVA       0.151230           0.058016 -0.007335        -0.011994
#
#                    DIAS_RESERVA
# METROS                 0.151230
# _PRECIO_VENTA_num      0.058016
# Edad                  -0.007335
# DIAS_COTIZACION       -0.011994
# DIAS_RESERVA           1.000000
# 8) Distribuciones (METROS, PRECIO_VENTA, PRECIO_POR_M2)
# Pearson r: PearsonRResult(statistic=np.float64(0.109757924192913), pvalue=np.float64(4.7087007974728745e-05))
# Spearman rho: SignificanceResult(statistic=np.float64(-0.052780868033291885), pvalue=np.float64(0.05088252105697377))
#
# 9) Precio por m2 promedio por TIPOLOGIA y por ComunaProyecto (top 20)
#              count     median       mean        std
# TIPOLOGIA
# 2D/2B/K        786   0.000000  15.498295  29.108664
# 2D/2B          416   0.000000  15.389593  34.550211
# 2D/1B/K(MD)     91   0.000000   7.297485  23.658419
# STUDIO          21  67.294815  40.521111  39.788722
# 2D/2B/CA        20   0.000000   0.000000   0.000000
# 1D/1B           15  63.728235  56.357438  24.263621
# 3D + 2B         12   0.000000   0.000000   0.000000
# 3D/2B            8   0.000000   9.891816  27.978280
# 2D/1B            0        NaN        NaN        NaN
# 1D/1B/K          0        NaN        NaN        NaN
# 1D/1B CA         0        NaN        NaN        NaN
# 2D/2B  K CA      0        NaN        NaN        NaN
# 2D/2B KA         0        NaN        NaN        NaN
# 1.5D/1B K        0        NaN        NaN        NaN
# 1,5D/2B          0        NaN        NaN        NaN
# 1,5D/1B          0        NaN        NaN        NaN
# 2D/2B/K(M)       0        NaN        NaN        NaN
# 2D/2B/C          0        NaN        NaN        NaN
# 2D/2B K          0        NaN        NaN        NaN
# 2D/3B CA         0        NaN        NaN        NaN
#                 count     median       mean
# ComunaProyecto
# San Joaquin       831   0.000000  14.708337
# Vitacura          350   0.000000  15.511658
# La Florida         91   0.000000   7.297485
# Ñuñoa              41   0.000000   7.906452
# Stgo. Centro       34  66.731601  63.222325
# Viña               22   0.000000  10.624444
# Independencia       0        NaN        NaN
# Concepcion          0        NaN        NaN
# Con Con             0        NaN        NaN
# La Reina            0        NaN        NaN
# Providencia         0        NaN        NaN
# Las Condes          0        NaN        NaN
# Macul               0        NaN        NaN
# 10) Tendencias temporales (FECHACOTIZACION)
# /tmp/ipykernel_48027/3974190355.py:114: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   tmp = df.set_index('FECHACOTIZACION').resample('M').agg({'_PRECIO_VENTA_num':['count','median','mean']})
#                  _PRECIO_VENTA_num_count  _PRECIO_VENTA_num_median  \
# FECHACOTIZACION
# 2023-11-30                           679                       0.0
# 2023-12-31                           377                       0.0
# 2024-01-31                           696                       0.0
# 2024-02-29                           589                       0.0
# 2024-03-31                           600                       0.0
# 2024-04-30                           679                       0.0
# 2024-05-31                           752                       0.0
# 2024-06-30                           992                       0.0
# 2024-07-31                           972                       0.0
# 2024-08-31                           565                       0.0
# 2024-09-30                           659                       0.0
# 2024-10-31                           256                       0.0
#
#                  _PRECIO_VENTA_num_mean
# FECHACOTIZACION
# 2023-11-30                   713.093446
# 2023-12-31                   898.931910
# 2024-01-31                   676.325374
# 2024-02-29                   603.195518
# 2024-03-31                   602.841000
# 2024-04-30                   971.250972
# 2024-05-31                   823.907088
# 2024-06-30                   924.930565
# 2024-07-31                  1221.113549
# 2024-08-31                   740.211274
# 2024-09-30                   761.065478
# 2024-10-31                  1290.473047
# 11) Detección outliers (IQR) en METROS y PRECIO_VENTA
#                    low   high  n_outliers  pct_outliers
# METROS            -2.0  158.0         0.0      0.000000
# _PRECIO_VENTA_num  0.0    0.0     14008.0      0.165386
# PRECIO_POR_M2      0.0    0.0       278.0      0.203068
# 12) Recomendaciones rápidas:
# - Revisar alta proporción de nulos en 'METROS' y varias fechas; imputar o filtrar según análisis.
# - Para análisis de precios usar 'PRECIO_POR_M2' y winsorizar o log-transform si conviene.
# - Agrupar por TIPOLOGIA/ComunaProyecto/PROYECTO para comparar valores y detectar anomalías por subgrupos.
# - Verificar registros con PRECIO_VENTA==0 o METROS==0; pueden ser errores o placeholders.
# - Documentar transformaciones y filtrados antes de modelar.

# %% [markdown]
# ## **Análisis univariado**
#
# El análisis univariado es el análisis de una sola variable a la vez para resumir sus características principales y comprender su comportamiento. Es la etapa inicial en el análisis de datos: permite describir, visualizar y detectar problemas (valores faltantes, outliers, distribuciones extrañas) antes de estudiar relaciones entre variables.
#
# ### Objetivos principales
# - Resumir la variable con estadísticas clave.
# - Visualizar su distribución para identificar forma, sesgo y valores atípicos.
# - Detectar problemas de calidad de datos (missing, errores, outliers).
# - Decidir transformaciones o categorizaciones necesarias para análisis posteriores.
#
# ### Qué examinar según el tipo de variable
# - Variables numéricas:
#     - Medidas de tendencia central: media, mediana, moda.
#     - Medidas de dispersión: desviación estándar, varianza, rango, IQR (rango intercuartílico).
#     - Forma de la distribución: sesgo (skewness), curtosis.
#     - Valores atípicos y posibles transformaciones (log, sqrt).
# - Variables categóricas:
#     - Frecuencias absolutas y relativas (proporciones).
#     - Modo, distribución de categorías y rarezas.
#     - Reagrupamiento si hay muchas categorías con baja frecuencia.
#
# ### Visualizaciones comunes
# - Numéricas: histograma, densidad (KDE), boxplot, violin plot.
# - Categóricas: barras, tablas de frecuencia, gráficos de pastel (con precaución).
# - Complementos: desviación estándar en gráficos, plot de cuantiles (QQ-plot) para evaluar normalidad.
#
# ### Pasos prácticos recomendados
# 1. Identificar el tipo y el rango de la variable.
# 2. Calcular estadísticas descriptivas básicas.
# 3. Visualizar la distribución y buscar outliers/missing.
# 4. Aplicar transformaciones o binning si es necesario.
# 5. Registrar hallazgos y decisiones para análisis posteriores.
#
# ### Consideraciones y errores comunes
# - No confiar sólo en la media si la distribución está sesgada; usar mediana.
# - Tratar outliers con cuidado: verificar si son errores o información válida.
# - Tener en cuenta el tamaño de la muestra: estadísticas en muestras pequeñas son inestables.
# - Documentar transformaciones para reproducibilidad.
#
# El análisis univariado es sencillo pero esencial: establece una base sólida para análisis más avanzados (bivariado y multivariado) y para la limpieza y modelado de datos.

# %% [markdown]
# ## **Análisis bivariado**
#
# El análisis bivariado estudia la relación entre dos variables para entender si están asociadas, cómo se relacionan (dirección, forma y fuerza) y si esa relación es estadísticamente significativa. Es el paso intermedio entre el análisis univariado y el multivariado, y ayuda a generar hipótesis sobre dependencias o efectos entre variables.
#
# ### Objetivos principales
# - Detectar asociación o dependencia entre dos variables.
# - Cuantificar la dirección (positiva/negativa), forma (lineal/no lineal) y fuerza de la relación.
# - Probar si la relación es estadísticamente significativa.
# - Visualizar la relación para identificar patrones, outliers o subgrupos.
#
# ### Tipos de pares y métodos comunes
# - **Numérica — Numérica**
#     - Visual: scatter plot, líneas de tendencia.
#
#     - Métricas: correlación de Pearson (lineal), Spearman (monótona), covarianza.
#
#     - Modelos: regresión lineal simple.
#
# - **Categórica — Categórica**
#     - Visual: tabla de contingencia, barras apiladas/múltiples.
#
#     - Pruebas: chi-cuadrado de independencia, test exacto de Fisher.
#
#     - Medida de fuerza: Cramér's V.
#
# - **Numérica — Categórica**
#     - Visual: boxplot, violín, barras con medias y errores.
#
#     - Pruebas: t-test (dos grupos), ANOVA (más de dos), test de Welch.
#
#     - Medidas: diferencia de medias, tamaño del efecto (Cohen's d).
#
# ### Pasos prácticos recomendados
# 1. Revisar calidad de datos (missing, outliers, escalas).
# 2. Visualizar la relación con la gráfica adecuada.
# 3. Calcular estadístico descriptivo (correlación, tablas de frecuencia, medias por grupo).
# 4. Aplicar prueba estadística de significancia.
# 5. Interpretar resultados considerando plausibilidad y posibles variables confusoras.
#
# ### Errores y consideraciones
# - Correlación no implica causalidad.
# - Confusores pueden crear asociaciones espurias.
# - Outliers pueden distorsionar correlaciones.
# - Asegurar tamaño muestral suficiente para pruebas.
# - Normalidad y homogeneidad de varianzas condicionan algunas pruebas; usar alternativas no paramétricas si es necesario.
#
# ### Ejemplos
#
# 1) Numérica — Numérica
#      - Ejemplo: METROS vs PRECIO.
#      - Qué hacer: scatter plot + recta de regresión + calcular correlación de Pearson.
#      - Interpretación típica: correlación positiva alta → a mayor superficie, mayor precio; si r ≈ 0.8 sugiere relación fuerte, pero revisar heterocedasticidad y outliers.
#
# 2) Categórica — Categórica
#      - Ejemplo: FORMA_PAGO (Contado/Crédito) vs ESTADO (Reservado/No vendido).
#      - Qué hacer: tabla de contingencia, gráfico de barras apiladas, test chi-cuadrado.
#      - Interpretación típica: chi-cuadrado significativo → la distribución de ESTADO depende de la FORMA_PAGO; usar Cramér's V para medir la fuerza.
#
# 3) Numérica — Categórica
#      - Ejemplo: EDAD vs PAGO_CONTADO (Sí/No).
#      - Qué hacer: boxplots por grupo, t-test o Mann–Whitney si no normal.
#      - Interpretación típica: diferencia de medianas significativa → un grupo (p. ej. quienes pagan contado) tiene mayor edad promedio.
#
# 4) Mixto/práctico aplicado (opcional)
#      - Ejemplo: LATITUD/LONGITUD vs PRECIO por COMUNA (categórica).
#      - Qué hacer: mapa de calor o scatter geoespacial por precio promedio, ANOVA para comparar medias por comuna.
#      - Interpretación típica: zonas con mayor precio muestran cluster espacial; controlar por METROS y TIPOLOGIA para aislar efecto espacial.
#
# Usar estos análisis para formular hipótesis, no para concluir causalidad. Documentar métodos y resultados para reproducibilidad.

# %% [markdown]
# ### Ejemplos de análisis bivariado
#
# Ajustar rutas y limpiar nulos según el dataset (ej: 'ventas.csv') antes de ejecutar.
#
# 1) Numérica — Numérica (METROS vs PRECIO): scatter, línea de regresión, correlaciones y regresión lineal

# %%
# Scatter + regresión
sns.regplot(x='METROS', y='PRECIO_VENTA', data=df, scatter_kws={'s':10}, line_kws={'color':'red'})
plt.title('METROS vs PRECIO')
plt.show()

# Correlaciones
x = df['METROS'].dropna()
y = df['PRECIO_VENTA'].dropna()
ix = x.index.intersection(y.index)
print('Pearson:', stats.pearsonr(x.loc[ix], y.loc[ix]))
print('Spearman:', stats.spearmanr(x.loc[ix], y.loc[ix]))

# Regresión lineal sencilla
X = sm.add_constant(x.loc[ix])
model = sm.OLS(y.loc[ix], X).fit()
print(model.summary())
# Out:
# Pearson: PearsonRResult(statistic=np.float64(-0.006711265879329291), pvalue=np.float64(0.5737257030333979))
# Spearman: SignificanceResult(statistic=np.float64(-0.09823889685353511), pvalue=np.float64(1.5219244254278786e-16))
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PRECIO_VENTA   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.3165
# Date:                Sat, 22 Nov 2025   Prob (F-statistic):              0.574
# Time:                        23:21:43   Log-Likelihood:                -59191.
# No. Observations:                7029   AIC:                         1.184e+05
# Df Residuals:                    7027   BIC:                         1.184e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        233.8198     49.102      4.762      0.000     137.565     330.075
# METROS        -0.3657      0.650     -0.563      0.574      -1.640       0.909
# ==============================================================================
# Omnibus:                     8127.652   Durbin-Watson:                   0.390
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           597770.948
# Skew:                           6.274   Prob(JB):                         0.00
# Kurtosis:                      46.401   Cond. No.                         283.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 2) Categórica — Categórica (FORMA_PAGO vs ESTADO): tabla de contingencia, chi-cuadrado y Cramér's V

# %%
import numpy as np

# Tabla de contingencia y gráfico
ct = pd.crosstab(df['FORMA_PAGO'], df['ESTADO'])
plt.figure(figsize=(12,6))
ct.plot(kind='bar', stacked=False)
plt.title('FORMA_PAGO vs ESTADO')
plt.show()

# Chi-cuadrado
chi2, p, dof, exp = stats.chi2_contingency(ct)
n = ct.values.sum()
phi2 = chi2 / n
r, k = ct.shape
cramers_v = np.sqrt(phi2 / min(k-1, r-1))
print('chi2 p-value:', p)
print("Cramér's V:", cramers_v)
# Out:
# chi2 p-value: 0.0
# Cramér's V: 0.30091435361902796

# %%
3) Numérica — Categórica (EDAD vs PAGO_CONTADO): boxplot y prueba de diferencia de medias (t-test / Mann–Whitney)

# %%
# Boxplot por grupo
sns.boxplot(x='PRECIO_VENTA', y='EDAD', data=df)
plt.title('EDAD por PAGO_CONTADO')
plt.show()

# Tests
g1 = df[df['PRECIO_VENTA']=='Sí']['EDAD'].dropna()
g2 = df[df['PRECIO_VENTA']=='No']['EDAD'].dropna()

# t-test de Welch
tstat, pval = stats.ttest_ind(g1, g2, equal_var=False)
print('t-test p-value:', pval)

# Si no normal, Mann-Whitney
mw_stat, mw_p = stats.mannwhitneyu(g1, g2, alternative='two-sided')
print('Mann-Whitney p-value:', mw_p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Boxplot por grupo
# ----> 2 sns.boxplot(x='PRECIO_VENTA', y='EDAD', data=df)
#       3 plt.title('EDAD por PAGO_CONTADO')
#       4 plt.show()
#
# File ~/Documentos/github/Cienciadedatos/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)   1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
#    1603         legend=legend,
#    1604     )
#    1606     if ax is None:
#    1607         ax = plt.gca()
#
# File ~/Documentos/github/Cienciadedatos/.venv/lib/python3.12/site-packages/seaborn/categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)     64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)     76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~/Documentos/github/Cienciadedatos/.venv/lib/python3.12/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/Documentos/github/Cienciadedatos/.venv/lib/python3.12/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/Documentos/github/Cienciadedatos/.venv/lib/python3.12/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/Documentos/github/Cienciadedatos/.venv/lib/python3.12/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `EDAD` for `y`. An entry with this name does not appear in `data`.

# %% [markdown]
# 4) Espacial / Mixto (PRECIO geolocalizado por COMUNA): mapa simple / scatter con color por precio promedio

# %% [markdown]
# **Notas rápidas:**
# - Manejar nulos antes de pruebas/statistics.
#
# - Revisar supuestos (normalidad, homogeneidad de varianzas) y usar tests no paramétricos si corresponde.
#
# - Documentar transformaciones (log, winsorize) y justificar decisiones.

# %% [markdown]
# ## **Análisis multivariado**
#
# El análisis multivariado estudia simultáneamente más de dos variables para entender relaciones, patrones y dependencias entre ellas. A diferencia del análisis univariado o bivariado, considera la interacción entre múltiples variables y permite responder preguntas como: ¿qué conjunto de variables explican mejor una respuesta?, ¿existen grupos con comportamientos similares?, ¿qué variables aportan más información para un modelo predictivo?
#
# ### Objetivos principales
# - Identificar relaciones y dependencias entre varias variables a la vez.
# - Reducir la dimensionalidad sin perder la mayor parte de la información (p.ej. PCA).
# - Construir modelos predictivos multivariados (regresión múltiple, clasificación).
# - Detectar estructuras ocultas: clusters, factores latentes, interacciones.
# - Seleccionar variables relevantes y evaluar su importancia conjunta.
#
# ### Métodos comunes
# - Reducción de dimensionalidad: PCA, t-SNE, UMAP.
# - Modelos predictivos: regresión lineal múltiple, regresión logística, árboles, random forest.
# - Agrupamiento: k-means, DBSCAN, clustering jerárquico.
# - Análisis de factores y componentes: Análisis factorial, ICA.
# - Técnicas para variables mixtas: análisis discriminante, modelos GLM, modelos de mezcla.
#
# ### Pasos prácticos recomendados
# 1. Preparar datos: tratar nulos, escalado y codificación de categorías.
# 2. Explorar correlaciones y multicolinealidad (matriz de correlación, VIF).
# 3. Aplicar reducción de dimensionalidad si hay muchas variables.
# 4. Probar modelos apropiados según la tarea (predicción, clustering, segmentación).
# 5. Validar y evaluar (cross-validation, métricas apropiadas).
# 6. Interpretar y comunicar hallazgos: coeficientes, importancia de variables, perfiles de cluster.
#
# ### Ejemplos
# en Python (asumiendo que `ventas` ya está cargado en el notebook)
#
# 1) Reducción de dimensionalidad con PCA (explorar estructuras generales)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

cols = ['METROS', 'PRECIO', 'EDAD']
df_pca = ventas[cols].dropna()

X = StandardScaler().fit_transform(df_pca)
pca = PCA(n_components=2)
pcs = pca.fit_transform(X)

plt.figure(figsize=(7,5))
plt.scatter(pcs[:,0], pcs[:,1], alpha=0.6, s=20)
plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%})')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%})')
plt.title('PCA: primeros dos componentes')
plt.grid(alpha=0.2)
plt.show()

print('Varianza explicada total (2 comps):', pca.explained_variance_ratio_.sum())

# %% [markdown]
# **Interpretación:** el gráfico muestra si los datos tienen direcciones principales de variación; la varianza explicada indica cuánto resumen los primeros componentes.
#
# 2) Regresión lineal múltiple (predecir PRECIO usando varias variables)

# %%
import statsmodels.formula.api as smf

df_reg = ventas[['PRECIO', 'METROS', 'EDAD']].dropna()
model = smf.ols('PRECIO ~ METROS + EDAD', data=df_reg).fit()
print(model.summary())

# %% [markdown]
# **Interpretación:** revisar coeficientes, p-values y R^2 para entender qué variables contribuyen a explicar el precio manteniendo las demás constantes.
#
# 3) Clustering (segmentación de inmuebles por ubicación y precio)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

df_cl = ventas[['LONGITUD', 'LATITUD', 'PRECIO']].dropna()
X = StandardScaler().fit_transform(df_cl)
kmeans = KMeans(n_clusters=4, random_state=0).fit(X)
df_cl = df_cl.assign(cluster=kmeans.labels_)

plt.figure(figsize=(8,6))
sns.scatterplot(x='LONGITUD', y='LATITUD', hue='cluster', size='PRECIO',
                data=df_cl, palette='tab10', alpha=0.7, sizes=(20,200))
plt.title('Clusters geoespaciales con precio')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# **Interpretación:** los clusters pueden revelar zonas con comportamientos similares de precio y ubicación; útil para segmentación comercial.
#
# 4) Clasificación (logística) — ejemplo simple: predecir pago al contado según edad e ingreso

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

df_clf = ventas[['PAGO_CONTADO', 'EDAD', 'INGRESO']].dropna()
df_clf = df_clf[df_clf['PAGO_CONTADO'].isin(['Sí','No'])].copy()
df_clf['PAGO_BIN'] = (df_clf['PAGO_CONTADO'] == 'Sí').astype(int)

X = df_clf[['EDAD', 'INGRESO']]
y = df_clf['PAGO_BIN']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=0)

clf = LogisticRegression(max_iter=200).fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
print('Coeficientes:', dict(zip(X.columns, clf.coef_[0])))

# %% [markdown]
# **Interpretación:** métricas de precisión/recall y coeficientes indican cómo edad e ingreso se asocian con la probabilidad de pagar al contado.
#
# Notas finales
# - Siempre escalar variables numéricas antes de métodos sensibles a la escala (PCA, k-means, regularización).
#
# - Revisar multicolinealidad antes de interpretar coeficientes de regresión múltiple (ej. VIF).
#
# - Validar modelos con particiones o cross-validation y reportar métricas relevantes.
#
# Estos ejemplos son plantillas prácticas: adáptalas al contexto del proyecto (selección de variables, tratamiento de nulos, codificación de categorías y validación).
