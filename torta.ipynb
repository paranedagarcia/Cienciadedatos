# %%
import matplotlib.pyplot as plt

labels = [
    "Relator",
    "Soporte integral",
    "Gestión de pagos",
    "Suscripciones de aplicaciones",
    "Servicios Cloud",
    "Difusión"
]

sizes = [65, 10, 3, 8, 10, 4]

plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, autopct='%1.0f%%')
plt.title("Distribución de Costos / Recursos")
plt.show()
